# %%
# Questão 01

# %%
#Questão 03
def programa03():
      while True:
        print('escolha uma opção:')
        print('1 - parcelado em 3x \n 2- parcelado em 5x \n 3- parcelado em em 9x \n 4- sair do programa')
        n = int(input())
        if n == 1:
          pd = float(input('informe o valor do produto: '))
          par = pd/3
          print('valor da parcela',par, 'valor total: ',pd)
        elif n == 2:
          pd = float(input('informe o valor do produto: '))
          par = (pd/5)
          parj = par*(2/100)
          parf = parj+par
          valor_final = parf*5
          valor_final = str('%.2f'%valor_final)
          print('valor da parcela',parf, 'valor total: ',valor_final)

# %%
programa03()
# Out:
# escolha uma opção:
# 1 - parcelado em 3x
#  2- parcelado em 5x
#  3- parcelado em em 9x
#  4- sair do programa

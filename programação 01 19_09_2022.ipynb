# %%
# EXERCICIO 01
try:
  with open('Controle de fluxo.html','r',encoding='utf-8') as f:
    contator = 0
    for linha in f:
      if 'fluxo' in linha.lower() or 'python' in linha.lower()
      contator += 1
      print(contator)
except FileNotFoundError:
  print('arquivo inválido')

# %%
# EXERCICIO 02
try:
  with open('contatos.txt','w',encoding='utf-8') as f:
    nome = input('Digite seu nome')
    telefone = input('Digite seu telefone')
    if len(telefone) != 9:
      raise Exception("Código inválido: não é numérico")

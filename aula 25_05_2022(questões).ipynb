# %%
def q01(a,b):
  consumo = 312*a
  precof = consumo/b
  return precof
def q03

# %%
def modulo_1():
  preco_gasolina = float(input("Digite o preço da gasolina: "))
  autonomia_carro = float(input("Digite a autonomia do carro: "))
  preco_final = q01(preco_gasolina,autonomia_carro)
  preco_final = str('%.2f'%preco_final)
  print("Valor esperado: ",preco_final)

# %%
modulo_1()
# Out:
# Digite o preço da gasolina: 4.1
# Digite a autonomia do carro: 8.5
# Valor esperado:  150.49

# %%
### Extend
linguagens = ['Python', 'Java', 'C++']
novas = ['Elixir', 'Dart', 'Julia']
linguagens.extend(novas)
print(linguagens)
### APPEND
linguagens = ['Python', 'Java', 'C++']
novas = ['Elixir', 'Dart', 'Julia']
linguagens.append(novas)
print(linguagens)

## questao 2 letra A
# cadeia 'AAABB ABBAA A'
# padrao = 'AA'
# cadeia[i:f] == padrao

#with open('arquivo1', 'r+', encoding='utf-8') as f:
 # for linha in f:
 #   f.write(linha[:-1]+',FREQ,TEM')

with open('arquivo1','r',encoding='utf-8') as f:
  linhas = f.readlines()
with open('arquivo1','w',encoding='utf-8') as f:
  f.write('seq,FREQ,TEM\n')
  for cadeia in linhas[1:]:
    freq = funcaoA(cadeia, 'ATCCG')
    tem = funcaoB(cadeia,'ATCCG')
    f.write(f'{1[:-1]},{freq},{tem}\n')

# %%
# menor valor da lista
# 1 - receber e armazenar a lista  em (l)
# 2 - menor = L[0]
# 3 - iterar a lista (l) com (x)
# 3.1 - x < menor?
# 3.1.1 - menor = x
# 4 - exibir menor

# %%
def menor_lista(l):
  menor = l[0]
  for x in l:
    if x<menor:
      menor = x
  return menor

# %%
menor_lista([5,9,8,10,3,8,96,9])
# Out:
# 3

# %%
# questão 3

def qt3 (al):
  mal = al[0]
  for x in al:
    if x > mal:
      mal = x
  return mal

# %%
qt3([1.7, 1.88, 1.5, 1.32, 1.68, 1.59 ])
# Out:
# 1.88

# %%
qt3([1.67, 1.54, 1.7, 1.43])
# Out:
# 1.7

# %%
qt3([1.5, 1.75, 1.67, 1.9, 1.56, 1.89])
# Out:
# 1.9

# %%
qt3([1.7, 1.7, 1.67, 1.55, 1.43 ])
# Out:
# 1.7

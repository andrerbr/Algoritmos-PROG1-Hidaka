# %%
def soma_lista(x):
  s = 0
  for  v in x:
    s = s + v
  return s

# %%
soma_lista([3,3,5,7,2])
# Out:
# 20

# %%
soma_lista([1,3,6])
# Out:
# 10

# %%
soma_lista([2,2,2,2])
# Out:
# 8

# %%
soma_lista([100,5,6,8,4,2,9])
# Out:
# 134

# %%
# QUESTÃO 14 DA LISTA
def qt_14(lnomes,lidades,i,f):
  L_Saida = []
  N = len(lnomes)
  for k in range(N):
    if  lidades[k]>= i and lidades[k] <= f:
      L_Saida.append(lnomes[k])
  return L_Saida

# %%
qt_14(['Ramon', 'Arnaldo', 'Raquel', 'Pedro', 'Rafael'],[23, 45, 27, 60, 45],20,30)
# Out:
# ['Ramon', 'Raquel']

# %%
list(range(6))
# Out:
# [0, 1, 2, 3, 4, 5]

# %%
L = [2,4,5,6,1,10]
soma = 0
N = len(L) # tamanho da lista / funcao
for k in range(N): # range = uma lista de 0 ate n-1 // posso iterar com k || n-1 = iterar ate o penultimo indice  || range(1) = um elementos // indice 0
    soma = soma + L[k]
print(soma)
# Out:
# 28

# %%
list(range(4,3)) # range com 2 valores, primeiro de onde a lista comeca, e o segundo é o ultimo valor da lista(n-1)
# Out:
# []

# %%
L = [2,4,5,6,1,10]
N = len(L)
for k in range(1,N):
  w = L[k] - L[k-1]
  print(w)
# Out:
# 2
# 1
# 1
# -5
# 9

# %%
L = [2,4,5,6,1,10]
N = len(L)
for k in range(1,N-1):
  w = L[k] - L[k+1]
print(w)
# Out:
# -9
